# %% [markdown]
# Chapter6. 예외처리

# %% [markdown]
# ##### 06-1 구문 오류와 예외
# ###### 구문오류: 프로그램 실행 전에 발생하는 오류
# ###### 예외 or 런타임 오류: 프로그램 실행 후에 발생하는 오류

# %%
# 구문 오류 : SyntaxError

print("#프로그램이 시작")
print("#예외를 강제로 발생!)  #<--닫는 따옴표로 문자열을 닫아 해결
# Out:
#   Cell In[1], line 4
#     print("#예외를 강제로 발생!)
#           ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
# 예외 : NameError

print("#프로그램 시작")

#list_a = [1,2,3,4,5] --> list_a를 정의해야 함
list_a[1]
# Out:
# #프로그램 시작
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 4
#       1 # 예외
#       3 print("#프로그램 시작")
# ----> 4 list_a[1]
#
# NameError: name 'list_a' is not defined

# %% [markdown]
# 기본 예외 처리
# 예외를 해결하는 모든 것을 '예외처리'
#
# ###### 1_조건문 사용
# ###### 2_try 구문 사용

# %%
#예외 상황

number_input_a = int(input("정수 업력 >>")) ##정수입력하면 OK, 그외는 valueError
print("원의 반지름:", number_input_a)
print("원의 둘레:", 2*3.14*number_input_a)
print("원의 넓이:", 3.14*number_input_a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 3
#       1 #예외 상황
# ----> 3 number_input_a = int(input("정수 업력 >>"))
#       4 print("원의 반지름:", number_input_a)
#       5 print("원의 둘레:", 2*3.14*number_input_a)
#
# ValueError: invalid literal for int() with base 10: '6.5'

# %%
#🐬조건문 장치로 예외 처리~

user_input_a = input("정수입력>>")

if user_input_a.isdigit():
    number_input_a=int(user_input_a)
    print("원의 반지름:", number_input_a)
    print("원의 둘레:", 2*3.14*number_input_a) 
    print("원의 넓이:", 3.14*number_input_a)
else:
    print("정수로 넣으라고!")
# Out:
# 정수로 넣으라고!

# %% [markdown]
# ##### 🐬try except 구문
#     try:
#     except:

# %%
#🐬try except라는 장치로 예외 처리~

try:
    user_input_a = int(input("정수입력>>"))

    print("원의 반지름:", number_input_a)
    print("원의 둘레:", 2*3.14*number_input_a) 
    print("원의 넓이:", 3.14*number_input_a)
except:
    print("무언가 잘못되었음 입력 잘한게 맞엄?")
# Out:
# 무언가 잘못되었음 입력 잘한게 맞엄?

# %% [markdown]
# ##### 🐬Try except 구문과 pass 키워드 조합
# ###### 어떤 부분에서 예외가 발생하는지 정도를 파악할 수 있는 상황에서 해당 코드가 딱히 중요한 부분이 아니라면, 프로그램이 강제 종료되는 것부터 막자는 목적으로 except 구문에 아무 것도 넣지 않고 try 구문을 사용하게 된다. 다음과 같이 pass 키워드 넣어 구문 내부에 아무 것도 넣지 않아 생기는 구문 오류 발생을 막자!
#     try:
#     except:
#         pass

# %%
#숫자로 변환되는 것들만 리스트에 넣기

list_input_a = ["52","273","32","스파이","103"]

list_number = []
for item in list_input_a:
    try:
        float(item)
        list_number.append(item)
    except:
        pass
print("{} 내부에 있는 숫자는".format(list_input_a))
print("{} 입니다".format(list_number))
# Out:
# ['52', '273', '32', '스파이', '103'] 내부에 있는 숫자는
# ['52', '273', '32', '103'] 입니다

# %% [markdown]
# ###### 숫자로 변환할 수 없는 문자열은 float(item)를 실행하 때 예외가 발생한다. try except 구문으로 감싸고 예외가 발생하지 않는 경우에만 list_number.append(item)가 실행되도록 만든 코드

# %% [markdown]
# ##### try except else 구문
#
# ###### try except 구문 뒤에 else 구문을 붙여 사용하면 예외가 발생하지 않았을 때 실행할 코드를 지정할 수 있음.
#     try:
#         예외가 발생할 가능성이 있는 코드
#     except:
#         예외가 발생했을 때 실행할 코드
#     else:
#         예외가 발생하지 않았을 때 실행할 코드

# %%
# try except else 구문으로 예외 처리

try:
    number_input_a = int(input("정수입력>>"))
except:
    print("정수를 입력하지 않음!")
else:
    print("원의 반지름:", number_input_a)
    print("원의 둘레:", 2*3.14*number_input_a)
    print("원의 넓이:", 3.14*number_input_a*number_input_a)
# Out:
# 원의 반지름: 8
# 원의 둘레: 50.24
# 원의 넓이: 200.96

# %% [markdown]
# ##### Finally 구문
# ###### 예외 처리 구문에서 가장 마지막에 사용할 수 있는 구문이다.
# ###### 예외가 발생하든 발생하지 않든 무조건 실행할 때 사용하는 코드
#     try:
#         예외 발생 가능
#     except:
#         예외 발생 했을 떄
#     else:
#         예외 발생 하지 않았을 때
#     finally:
#         무조건 실행할 코드

# %%
# finally 구문

try:
    number_input_a = int(input("정수입력>>"))

    print("원의 반지름:", number_input_a)
    print("원의 둘레:", 2*3.14*number_input_a)
    print("원의 넓이:", 3.14*number_input_a*number_input_a)
except:
    print("정수를 입력하지 않았다고")
else:
    print("예외가 발생하지 않았어")
finally:
    print("일단 프로그램이 어떻게든 끝이나긴 함")
# Out:
# 정수를 입력하지 않았다고
# 일단 프로그램이 어떻게든 끝이나긴 함

# %%
# try + else 구문 조합

try:
    number_input_a = int(input("정수입력~~"))

    print("원의 반지름:", number_input_a)
    print("원의 둘레:", 2*3.14*number_input_a)
    print("원의 넓이:", 3.14*number_input_a*number_input_a)
else:
    print("프로그램 정상 종료")
# Out:
#   Cell In[3], line 9
#     else:
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %%
# 파일이 제대로 닫혔는지 확인하기

try:
    file = open("info.txt","w")
    file.close()
except:
    print("오류발생")

print("#파일이 제대로 닫혔는가 확인")
print("file.closed:", file.closed)

##🎄항상 켜져 있는 프로그램을 데몬daemon, 서비스service라고 부른다.
#컴퓨터 성능을 감시하는 프로그램,파일의 변경을 감시하는 프로그램, 사용자에게 웹 페이지를 제공해주는
#웹 서버 등이 모두 데몬이자 서비스임
# Out:
# #파일이 제대로 닫혔는가 확인
# file.closed: True

# %%
#파일 처리 중간에 예외 발생
try:
    file = open("info.txt","w")
    예외.발생해라() #<--일부러 예외 발생!
    file.close()
except:
    print("오류발생함")

print("#파일이 제대로 닫혔는가 확인")
print("file.closed:", file.closed) #‼️false : 파일이 닫히지 않았음,반드시 finally 구문을 사용해서 파일을 닫아야 함
# Out:
# 오류발생함
# #파일이 제대로 닫혔는가 확인
# file.closed: False

# %%
# finally 구문 사용해 파일 닫기

try:
    file = open("info.txt","w")
    예외.발생해라() #<--일부러 예외 발생
except:
    print("오류 발생 ")
finally:
    file.close()
print("#파일이 제대로 닫혔는지 확인하기")
print("file.closed:", file.closed)
# Out:
# 오류 발생
# #파일이 제대로 닫혔는지 확인하기
# file.closed: True

# %%
#try except 구문 끝난 후 파일 닫기

try:
    file = open("info.txt","w")
    예외.발생해라() #<--일부러 예외 발생
except:
    print("오류 발생했슴둥~")

file.close()
print("#파일이 제대로 닫혔는지 확인하기")
print("file.closed:", file.closed)

#⬇️⬇️finally 키워드는 무조건 사용X, 코드가 깔끔해질 것 같다고 생각되는 경우에 사용하는것 ⬇️⬇️
# Out:
# 오류 발생했슴둥~
# #파일이 제대로 닫혔는지 확인하기
# file.closed: True

# %%
#🐬try 구문 내부에서 return 키워드를 사용하는 경우

def test():
    print("test() 함수의 첫 줄입니다~")
    try:
        print("try 구문이 실행되었습니다~")
        return
        print("try 구문의 return 키워드 뒤입니다~~")
    except:
        print("except 구문이 실행되었습니다~")
    else:
        print("else 구문이 실행되었습니다~")
    finally:
        print("finally 구문이 실행되었습니다~")
    print("test()함수의 마지막 줄입니다!")

test()
# Out:
# test() 함수의 첫 줄입니다~
# try 구문이 실행되었습니다~
# finally 구문이 실행되었습니다~

# %%
# finally 키워드 활용

def wirite_text_file(filename, text):
    try:
        file = open(filename, "w")
        return
        file.write(text)
    except:
        print("오류가 발생했어요")
    finally:
        file.clse()
wirite_text_file("text.txt", "안녕하세요!")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 12
#      10     finally:
#      11         file.clse()
# ---> 12 wirite_text_file("text.txt", "안녕하세요!")
#
# Cell In[14], line 11, in wirite_text_file(filename, text)
#       9     print("오류가 발생했어요")
#      10 finally:
# ---> 11     file.clse()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'clse'

# %%
# 반복문과 함께 사용하는 경우

print("프로그램이 시작되었습니다")
while True:
    try:
        print("try 구문이 실행됨")
        break
        print("try 구문의 break키워드 뒤")
    except:
        print("except 구문이 실행되었음")
    finally:
        print("finally 구문이 실행되었음")
    print("while 반복문의 마지막 줄입니다")
print("프로그램이 종료됨!")

# break키워드로 try 구문 전체를 빠져나가도 finally 구문이 실행
# Out:
# 프로그램이 시작되었습니다
# try 구문이 실행됨
# finally 구문이 실행되었음
# 프로그램이 종료됨!

# %% [markdown]
# ##### 마무리
# ###### 1.구문오류: 프로그램의 문법적인 오류로 프로그램이 실행조차 되지 않게하는 오류
# ###### 2.예외(런타임에러): 프로그램 실행 중에 발생, try except 구문 등으로 처리 가능
# ###### 3.기본예외처리: 조건문 등을 사용해 예외를 처리
# ###### 4.try excpt 구문: 예외 처리에 특화된 구문

# %% [markdown]
# ##### 06-2 예외 고급
# ###### 예외 객체 exception object
#     try:
#         예외 발생 가능 구문
#     except 예외종류 as 예외 객체 활용할 변수 이름:
#         예외 발생 했을 때 실행할 구문

# %%
# 예외 객체 p26
#--예외의 종류를 모를 때는 '모든 예외의 어머니'인 🐬Exception을 사용
#🐬Exception은 클래스이다.

try:
    number_input_a = int(input("정수를 입력하시오~>>"))
    print("원의 반지름:", number_input_a)
    print("원의 둘레:", 2*3.14*number_input_a)
    print("원의 넓이:", 3.14*number_input_a*number_input_a)
except Exception as exception:
    print("type(exception):", type(exception))
    print("exception:", exception)
# Out:
# type(exception): <class 'ValueError'>
# exception: invalid literal for int() with base 10: '??????'

# %%
# 예외 구분하기
#--except 구문을 if 조건문처럼 사용해서 예외를 구분할 수 있다.


#🐬여러 가지 예외가 발생할 수 있는 코드
list_number = [52,273,32,72,100]
try:
   number_input = int(input("정수입력_"))
   print("{}번째 요소:{}".format(number_input, list_number[number_input]))
except Exception as excetpion:
    print("type(exception):", type(exception))
    print("exception:", exception)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 9
#       8    number_input = int(input("정수입력_"))
# ----> 9    print("{}번째 요소:{}".format(number_input, list_number[number_input]))
#      10 except Exception as excetpion:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 11
#       9    print("{}번째 요소:{}".format(number_input, list_number[number_input]))
#      10 except Exception as excetpion:
# ---> 11     print("type(exception):", type(exception))
#      12     print("exception:", exception)
#
# NameError: name 'exception' is not defined

# %% [markdown]
# ##### 예외 구분하기
#     try:
#         예외 발생 가능 구문
#     except 예외 종류A:
#         예외A가 발생했을 때 실행 될 구문
#     except 예외 종류B:
#         예외B가 발생했을 때 실행 될 구문
#     except 예외 종류C:
#         예외C가 발생했을 때 실행 될 구문

# %%
# 예외 구분하기

list_number = [52,273,32,72,100]
try:
   number_input = int(input("정수입력_"))
   print("{}번째 요소:{}".format(number_input, list_number[number_input]))

except ValueError:
    print("정수를 입력해주쎄욥")
except IndexError:
    print("리스트의 인덱스를 벗어났어요!")
# Out:
# 리스트의 인덱스를 벗어났어요!

# %%
# 예외 구분 구문과 예외 객체

list_number = [52,273,32,72,100]
try:
   number_input = int(input("정수입력>>>"))
   print("{}번째 요소:{}".format(number_input, list_number[number_input]))
except ValueError as exception:
    print("정수를 입력해 주세요")
    print("exception:". exception)
except IndexError as exception:
    print("리스트의 인덱스를 벗어났어요")
    print("exception:". exception)
# Out:
# 리스트의 인덱스를 벗어났어요
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[33], line 6
#       5    number_input = int(input("정수입력>>>"))
# ----> 6    print("{}번째 요소:{}".format(number_input, list_number[number_input]))
#       7 except ValueError as exception:
#
# IndexError: list index out of range
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 12
#      10 except IndexError as exception:
#      11     print("리스트의 인덱스를 벗어났어요")
# ---> 12     print("exception:". exception)
#
# AttributeError: 'str' object has no attribute 'exception'

# %%
#🍟모든 예외 잡기

## 예외 처리를 했지만 예외를 못 잡는 경우
list_number = [52,273,32,72,100]
try:
   number_input = int(input("정수입력>>>"))
   print("{}번째 요소:{}".format(number_input, list_number[number_input]))
   예외.발생해주세요() ###‼️‼️‼️이 부분에서 잡지 않은 예외 발생!!
except ValueError as exception:
    print("정수를 입력해 주세요")
    print(type(exception). exception)
except IndexError as exception:
    print("리스트의 인덱스를 벗어났어요")
    print(type(exception). exception)

###‼️‼️‼️이 부분에서 잡지 않은 예외 발생으로 프로그램이 강제 종료됨 
##그래서 else구문처럼 마지막에는 Exception을 넣어 방지
# Out:
# 3번째 요소:72
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 8
#       6    number_input = int(input("정수입력>>>"))
#       7    print("{}번째 요소:{}".format(number_input, list_number[number_input]))
# ----> 8    예외.발생해주세요()
#       9 except ValueError as exception:
#      10     print("정수를 입력해 주세요")
#
# NameError: name '예외' is not defined

# %%
#🐬모든 예외 잡기

list_number = [52,273,32,72,100]
try:
   number_input = int(input("정수입력>"))
   print("{}번째 요소:{}".format(number_input, list_number[number_input]))
   예외.발생해주세요() 
except ValueError as exception:
    print("정수를 입력해 주세요")
    print(type(exception). exception)
except IndexError as exception:
    print("리스트의 인덱스를 벗어났어요")
    print(type(exception). exception)

except Exception as exception:
    print("미리 파악하지 못한 예외가 발생했어요!!")
    print(type(exception). exception)
# Out:
# 3번째 요소:72
# 미리 파악하지 못한 예외가 발생했어요!!
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 7
#       6    print("{}번째 요소:{}".format(number_input, list_number[number_input]))
# ----> 7    예외.발생해주세요()
#       8 except ValueError as exception:
#
# NameError: name '예외' is not defined
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 17
#      15 except Exception as exception:
#      16     print("미리 파악하지 못한 예외가 발생했어요!!")
# ---> 17     print(type(exception). exception)
#
# AttributeError: type object 'NameError' has no attribute 'exception'

# %%
# 🍰raise 구문
#--아직 구현되지 않은 부분에서 강제로 예외 발생시키기~~

number = input("정수 입력")
number = int(number)

if number > 0:
    raise NotImplementedError
else:
    raise NotImplementedError
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[40], line 8
#       5 number = int(number)
#       7 if number > 0:
# ----> 8     raise NotImplementedError
#       9 else:
#      10     raise NotImplementedError
#
# NotImplementedError:

# %% [markdown]
# ##### 마무리
# ###### 1.예외 객체 :예외와 관련된 정보를 담고 있는 객체
# ###### 2.raise 구문: 예외를 강제로 발생시킬 때 사용
# ###### 3.깃허브: 소셜 코딩 사이트
