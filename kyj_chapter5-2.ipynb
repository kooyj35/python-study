# %% [markdown]
# #05-2 함수의 활용

# %%
## 재귀 함수
## 팩토리얼(factorial) ; n! = (n-0)*(n-1)*(n-2)*...*1

#1. 반복문으로 팩토리얼 구하기
#--start부터 end까지 더하는 함수를 곱하는 함수로 바꾸기만 하면 됨!

#p293
# 함수 선언
def factorial(n):
    #변수 선언
    output = 1 #***결과를 저장할 변수 output을 1로 초기화, 곱셈의 항등원은 1이기 때문***
    #반복문을 돌려 숫자를 더함
    for i in range(1, n + 1):
        output *= i #***output = output*i 와 동일
    #리턴
    return output
#함수 호출
print("1!:", factorial(1))
print("2!:", factorial(2))
print("3!:", factorial(3))
print("4!:", factorial(4))
print("5!:", factorial(5))
# Out:
# 1!: 1
# 2!: 2
# 3!: 6
# 4!: 24
# 5!: 120

# %%
#2. 재귀 함수로 팩토리얼 구하기
#--재귀(recursion)란 '자기 자신을 호출하는 것'을 의미
# 표현방법[1] --팩토리얼(factorial) ; n! = (n-0)*(n-1)*(n-2)*...*1
# 표현방법[2] --factorial(n) = n* factorial(n-1) (n>=1 일때)

#p294
def factorial(n):
    #n이 0이라면 1을 리턴
    if n == 0:
        return 1
    #n이 0이 아니라면 n*(n-1)!을 리턴
    else:
        return n* factorial(n-1)
print("1!:", factorial(1))
print("2!:", factorial(2))
print("3!:", factorial(3))
print("4!:", factorial(4))
print("5!:", factorial(5))
# Out:
# 1!: 1
# 2!: 2
# 3!: 6
# 4!: 24
# 5!: 120

# %%
# 재귀 함수의 문제
#--재귀 함수는 상황에 따라서 같은 것을 기하급수적으로 많이 반복하는 문제가 있다.
#--"메모화 기술" : 재귀 함수로 인해 발생하는 문제를 해결할 수 있다.

#재귀 함수로 구현한 "피보나치 수열"-1
#--피보나치 수열 : '토끼는 어떠한 속도로 번식하는가'와 같은 연구에 사용되는 수열
def fibonacci(n):
    if n == 1:
        return 1
    if n == 2:
        return 1
    else:
        return fibonacci(n-1) + fibonacci (n-2)
     
print("fibonacci(1):", fibonacci(1))
print("fibonacci(2):", fibonacci(2))
print("fibonacci(3):", fibonacci(3))
print("fibonacci(4):", fibonacci(4))
print("fibonacci(5):", fibonacci(5))
# Out:
# fibonacci(1): 1
# fibonacci(2): 1
# fibonacci(3): 2
# fibonacci(4): 3
# fibonacci(5): 5

# %%
#재귀 함수로 구현한 "피보나치 수열"-2

#변수 선언
counter = 0
#함수 선언
def fibonacci(n):
    #어떤 피보나치 수를 구하는지 출력
    print("fibonacci({})를 구합니다.".format(n))
    global counter
    counter += 1
    #피보나치 수를 구함
    if n == 1:
        return 1
    if n == 2:
        return 1
    else:
        return fibonacci(n-1)+fibonacci(n-2)
    #함수 호출
fibonacci(10)
print("---")
print("fibonacci(10) 계산에 활용된 덧셈 횟수는 {}번입니다.".format(counter))
# Out:
# fibonacci(10)를 구합니다.
# fibonacci(9)를 구합니다.
# fibonacci(8)를 구합니다.
# fibonacci(7)를 구합니다.
# fibonacci(6)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(6)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(7)를 구합니다.
# fibonacci(6)를 구합니다.
# ...

# %% [markdown]
# ⬆⬆ 코드를 실행해보면 같은 것을 여러 번 연산
# fibonacci(10)을 구하는 데 109번이나 연산
#
# 기하급수적으로 늘어남
# 그 이유는 아래 그림과 같음
# **트리 내부에 있는 각각의 노드 값을 계산하려면 덧셈을 한 번씩 해야 하는데 노드가 한 번에 두 개씩 달려 있다. 한 번 구했던 값이라도 처음부터 다시 계산해야 해서 기하급수적으로 늘어남
# ![image.png](attachment:image.png)

# %%
## UnboundLocalError에 대한 처리
#재귀 함수로 구현한 피보나치 수열

counter = 0
def fibonacci(n):
    counter += 1
    #피보나치 수를 구함
    if n == 1:
        return 1
    if n == 2:
        return 1
    else:
        return fibonacci(n-1)+(n-2)
print(fibonacci(10))
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[7], line 14
#      12     else:
#      13         return fibonacci(n-1)+(n-2)
# ---> 14 print(fibonacci(10))
#
# Cell In[7], line 6, in fibonacci(n)
#       5 def fibonacci(n):
# ----> 6     counter += 1
#       7     #피보나치 수를 구함
#       8     if n == 1:
#
# UnboundLocalError: local variable 'counter' referenced before assignment

# %% [markdown]
# ⬆⬆ 파이썬은 함수 내부에서 함수 외부에 있는 변수를 참조(변수에 접근)하지 못함
#
# 함수 내부에서 함수 외부에 있는 변수라는 것을 설명하려면 'global 변수 이름' 사용

# %%
## 메모화 p301
#--재귀 함수에서 발생하는 가장 큰 문제는, 같은 값을 구하는 연산을 반복하고 있는 것
#따라서, 한 번만 계산하도록 코드를 수정하면 됨

# 메모 변수
dictionary = {
    1: 1,
    2: 1
}

# 함수 선언
def fibonacci(n):
    if n in dictionary:
        #메모가 되어 있으면 메모된 값을 리턴
        return dictionary[n]
    else:
        #메모가 되어 있지 않으면 값을 구함
        output = fibonacci(n-1) + fibonacci(n-2)
        dictionary[n] = output
        return output
    #함수 호출
print("fibonacci(10):", fibonacci(10))
print("fibonacci(20):", fibonacci(20))
print("fibonacci(30):", fibonacci(30))
print("fibonacci(40):", fibonacci(40))
print("fibonacci(50):", fibonacci(50))

#딕셔너리를 사용해서 한 번 계산한 값을 저장하는데 이를 '메모'한다고 표현한다.
#딕셔너리에 값이 메모되어있으면 처리를 수행하지 않고 곧바로 메모된 값을 돌려주면서
#코드의 속도를 빠르게 만든다.
# Out:
# fibonacci(10): 55
# fibonacci(20): 6765
# fibonacci(30): 832040
# fibonacci(40): 102334155
# fibonacci(50): 12586269025

# %%
## 조기 리턴 p302
# return 키워드를 중간에 사용하는 형태

def fibonacci(n):
    if n in dictionary:
        return dictionary[n]
    else:
        output = fibonacci(n-1)+fibonacci(n-2)
        dictionary[n]=output
        return output

# %%
## 위에서 아래와 같이 코드 변경
## 들여쓰기 단계가 줄어 코드를 더 쉽게 읽을 수 있음
## 이런 흐름 중간에 return 키워드 사용을 '조기리턴'이라고 함

def fibonacci(n):
    if n in dictionary:
        return dictionary[n]
    output = fibonacci(n-1)+fibonacci(n-2)
    dictionary[n]=output
    return output

# %%
#p303
